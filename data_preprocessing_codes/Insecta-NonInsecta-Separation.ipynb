# %%
import os
import random
import shutil

# %%
path = "/work/baskarg/Mojdeh/iNat_Project-mini-Insecta-2021/Data/2021_train_valid_mini_UnzipData/train_valid_Insecta/2021_train_mini/"
#dir_list = os.listdir(path)
#print(dir_list)
for it in os.scandir(path):
    print(it.path);
    str = it.path.split("/")[-1]
    if "Insecta" not in str:
        shutil.rmtree(it.path)
# Out:
# /work/baskarg/Mojdeh/iNat_Project-mini-Insecta-2021/Data/2021_train_valid_mini_UnzipData/train_valid_Insecta/2021_train_mini/06202_Plantae_Tracheophyta_Liliopsida_Liliales_Melanthiaceae_Trillium_nivale
# /work/baskarg/Mojdeh/iNat_Project-mini-Insecta-2021/Data/2021_train_valid_mini_UnzipData/train_valid_Insecta/2021_train_mini/03392_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_hybrida
# /work/baskarg/Mojdeh/iNat_Project-mini-Insecta-2021/Data/2021_train_valid_mini_UnzipData/train_valid_Insecta/2021_train_mini/06831_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Helianthus_petiolaris
# /work/baskarg/Mojdeh/iNat_Project-mini-Insecta-2021/Data/2021_train_valid_mini_UnzipData/train_valid_Insecta/2021_train_mini/04649_Animalia_Chordata_Mammalia_Artiodactyla_Cervidae_Cervus_canadensis
# ...

# %%
path = "/work/baskarg/Mojdeh/iNat_Project-mini-Insecta-2021/Data/2021_train_valid_mini_UnzipData/train_valid_Insecta/2021_valid/"
#dir_list = os.listdir(path)
#print(dir_list)
for it in os.scandir(path):
    print(it.path);
    str = it.path.split("/")[-1]
    if "Insecta" not in str:
        shutil.rmtree(it.path)

# %%
path = "/work/baskarg/Mojdeh/iNat_Project-mini-Insecta-2021/Data/2021_train_valid_mini_UnzipData/train_valid_NonInsecta/2021_train_mini/"
#dir_list = os.listdir(path)
#print(dir_list)
for it in os.scandir(path):
    print(it.path);
    str = it.path.split("/")[-1]
    if "Insecta" in str:
        shutil.rmtree(it.path)

# %%
path = "/work/baskarg/Mojdeh/iNat_Project-mini-Insecta-2021/Data/2021_train_valid_mini_UnzipData/train_valid_NonInsecta/2021_valid/"
#dir_list = os.listdir(path)
#print(dir_list)
for it in os.scandir(path):
    print(it.path);
    str = it.path.split("/")[-1]
    if "Insecta" in str:
        shutil.rmtree(it.path)
